# %% [markdown]
# # The Nigerian Map Showing: the states, geographic economic zones and the wild and scenic river system

# %% [markdown]
# ##ADMINISTRATIVE BOUNDARIES
# GET DATA FOR NIGERIA

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
Nigerian_states = gpd.read_file('C:/Users/OGNET/Desktop/Outreachy_Joshua_2022/Level4bycountry/NGA_ALL_states.json')

#importing and plotting the Nigerian_states Geojsonfile

# %% [markdown]
# ##Nigeria states' statistics

# %%
Nigerian_states
# Out:
#    country ISO3166_2                       name enname  \
# 0      NGA     NG-AB                       Abia
# 1      NGA     NG-AD                    Adamawa
# 2      NGA     NG-AK                  Akwa Ibom
# 3      NGA     NG-AN                    Anambra
# 4      NGA     NG-BA                     Bauchi
# 5      NGA     NG-BY                    Bayelsa
# 6      NGA     NG-BE                      Benue
# 7      NGA     NG-BO                      Borno
# 8      NGA     NG-CR                Cross River
# 9      NGA     NG-DE                      Delta
# 10     NGA     NG-EB                     Ebonyi
# 11     NGA     NG-ED                        Edo
# 12     NGA     NG-EK                      Ekiti
# 13     NGA     NG-EN                      Enugu
# 14     NGA     NG-FC  Federal Capital Territory
# 15     NGA     NG-GO                      Gombe
# 16     NGA     NG-IM                        Imo
# 17     NGA     NG-JI                     Jigawa
# ...

# %%
type(Nigerian_states)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
Nigerian_states.head()
# Out:
#   country ISO3166_2       name enname    locname offname        boundary  \
# 0     NGA     NG-AB       Abia              Abia          administrative
# 1     NGA     NG-AD    Adamawa           Adamawa          administrative
# 2     NGA     NG-AK  Akwa Ibom         Akwa Ibom          administrative
# 3     NGA     NG-AN    Anambra           Anambra          administrative
# 4     NGA     NG-BA     Bauchi            Bauchi          administrative
#
#    adminlevel wikidata           wikimedia           timestamp  \
# 0           4  Q320852       en:Abia State 2019-09-18 23:02:02
# 1           4  Q337514    en:Adamawa State 2019-02-26 10:52:47
# 2           4  Q424388  en:Akwa Ibom State 2019-09-19 22:03:02
# 3           4  Q117714    en:Anambra State 2019-02-26 10:52:47
# 4           4  Q503936     en:Bauchi State 2019-02-26 10:52:47
#
#                                             geometry
# 0  POLYGON ((7.14043 4.90063, 7.14375 4.89561, 7....
# ...

# %%
Nigerian_states.columns
# Out:
# Index(['country', 'ISO3166_2', 'name', 'enname', 'locname', 'offname',
#        'boundary', 'adminlevel', 'wikidata', 'wikimedia', 'timestamp',
#        'geometry'],
#       dtype='object')

# %%
len(Nigerian_states)
# Out:
# 37

# %%
Nigerian_states.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
Nigerian_states.geom_type
# Out:
# 0          Polygon
# 1          Polygon
# 2     MultiPolygon
# 3          Polygon
# 4          Polygon
# 5     MultiPolygon
# 6          Polygon
# 7          Polygon
# 8     MultiPolygon
# 9     MultiPolygon
# 10         Polygon
# 11         Polygon
# 12         Polygon
# 13         Polygon
# 14         Polygon
# 15         Polygon
# 16         Polygon
# 17         Polygon
# 18         Polygon
# 19         Polygon
# 20         Polygon
# 21         Polygon
# 22         Polygon
# 23         Polygon
# 24         Polygon
# 25         Polygon
# 26         Polygon
# 27         Polygon
# 28    MultiPolygon
# 29         Polygon
# 30         Polygon
# 31         Polygon
# 32    MultiPolygon
# 33         Polygon
# 34         Polygon
# 35         Polygon
# 36         Polygon
# dtype: object

# %% [markdown]
# ##Visualizing the Nigerian states

# %%
Nigerian_states.plot()
# Out:
# <AxesSubplot: >

# %%
Nigerian_states.plot("name")
# Out:
# <AxesSubplot: >

# %%
Nigerian_states.plot("name",legend=True)
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(1, figsize=(4.5,10))
Nigerian_states.plot(ax=ax, column="name", legend=True, legend_kwds={"loc": "center left"})
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.04,0.5))

# %% [markdown]
# Nigeria is located in western Africa on the Gulf of Guinea and has a total area of 923,768 km2 (356,669 sq mi),making it the world's 32nd-largest country. Its borders span 4,047 kilometres (2,515 mi), and it shares borders with Benin (773 km or 480 mi), Niger (1,497 km or 930 mi), Chad (87 km or 54 mi), and Cameroon (including the separatist Ambazonia) 1,690 km or 1,050 mi. Its coastline is at least 853 km (530 mi). Nigeria lies between latitudes 4° and 14°N and longitudes 2° and 15°E. With an area of 923,768 km² the country is more than three times the size of Italy or slightly more than twice the size of the U.S. state California. Nigeria's main rivers are the Niger and the Benue River, its highest point is Chappal Waddi with 2,419 m (7,936 ft), located in Taraba State, near the border with Cameroon. The highest point in Nigeria is Chappal Waddi at 2,419 m (7,936 ft). The main rivers are the Niger and the Benue, which converge and empty into the Niger Delta.
# This is one of the world's largest river deltas and the location of a large area of Central African mangroves.(https://en.wikipedia.org/wiki/Nigeria#Climate)
#
# The Federal Republic of Nigeria (its official name) has a population of of 177.5 million people making it Africa's most populous country. Capital city is Abuja located in the center of the nation, while Lagos is the primary port and largest city.
# Spoken languages are English (official), Hausa, Ibo, Yoruba, and others.(https://www.nationsonline.org/oneworld/map/nigeria-administrative-map.htm)

# %%
Nigeria_GEZ = gpd.read_file('C:/Users/OGNET/Desktop/Outreachy_Joshua_2022/Level2/NGA_AL2_Nigeria_GEZ.json')

# %%
Nigeria_GEZ
# Out:
#   country ISO3166_2     name                  gez_name  gez_code gez_abbrev  \
# 0     NGA            Nigeria       Tropical dry forest        13       TAwb
# 1     NGA            Nigeria     Tropical moist forest        12       TAwa
# 2     NGA            Nigeria  Tropical mountain system        16         TM
# 3     NGA            Nigeria       Tropical rainforest        11        TAr
# 4     NGA            Nigeria        Tropical shrubland        14       TBSh
# 5     NGA            Nigeria                     Water        90      Water
#
#    adminlevel                                           geometry
# 0           2  POLYGON ((4.17387 12.70964, 3.91224 12.72630, ...
# 1           2  POLYGON ((6.12077 12.05414, 6.01167 12.05684, ...
# 2           2  MULTIPOLYGON (((12.00401 7.51347, 12.00703 7.5...
# 3           2  MULTIPOLYGON (((6.72261 4.40102, 6.72370 4.401...
# 4           2  POLYGON ((5.83178 13.76125, 5.78032 13.78030, ...
# ...

# %%
type(Nigeria_GEZ)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
len(Nigeria_GEZ)
# Out:
# 6

# %%
Nigeria_GEZ.plot()
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(1, figsize=(4.5,10))
Nigeria_GEZ.plot(ax=ax, column="gez_name", legend=True, legend_kwds={"loc": "center left"})
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.04,0.5))

# %% [markdown]
# Nigeria has a varied landscape. The far south is defined by its tropical rainforest climate, where annual rainfall is 1,500 to 2,000 millimetres (60 to 80 in) per year.
# In the southeast stands the Obudu Plateau. Coastal plains are found in both the southwest and the southeast. Mangrove swamps are found along the coast.The area near the
# border with Cameroon close to the coast is rich rainforest and part of the Cross-Sanaga-Bioko coastal forests ecoregion,an important centre for biodiversity.
# It is a habitat for the drill primate, which is found in the wild only in this area and across the border in Cameroon.
# The areas surrounding Calabar, Cross River State, also in this forest, are believed to contain the world's largest diversity of butterflies.
# The area of southern Nigeria between the Niger and the Cross Rivers has lost most of its forest because of development and harvesting by increased population,and has been replaced by grassland.
#
# Everything in between the far south and the far north is savannah (insignificant tree cover, with grasses and flowers located between trees).
# Rainfall is more limited to between 500 and 1,500 millimetres (20 and 60 in) per year.The savannah zone's three categories are Guinean forest-savanna mosaic (Tropical moist forest),Sudan savannah (Tropical Dry forest), and Sahel savannah(Tropical Shrubland). Guinean forest-savanna mosaic (Tropical moist forest) is plains of tall grass interrupted by trees. Sudan savannah (Tropical Dry forest) is similar but with shorter grasses and shorter trees. Sahel savannah (Tropical Shrubland) consists of patches of grass and sand, found in the northeast. In the Sahel region(Tropical Shrubland), rain is less than 500 millimetres (20 in) per year, and the Sahara Desert is encroaching. In the dry northeast corner of the country lies Lake Chad, which Nigeria shares with Niger, Chad and Cameroon.(https://en.wikipedia.org/wiki/Nigeria#Climate)

# %%
Nigeria_WSR = gpd.read_file('C:/Users/OGNET/Desktop/Outreachy_Joshua_2022/Level2/NGA_AL2_Nigeria_WSR.json')

# %%
Nigeria_WSR
# Out:
#   country ISO3166_2     name SNAME  mg_code         IPCC  adminlevel  \
# 0     NGA            Nigeria    AC       23      Acrisol           2
# 1     NGA            Nigeria    AR        3     Arenosol           2
# 2     NGA            Nigeria    FL       20     Fluvisol           2
# 3     NGA            Nigeria    GL        7      Gleysol           2
# 4     NGA            Nigeria    LX        6      Lixisol           2
# 5     NGA            Nigeria    VR        5     Vertisol           2
# 6     NGA            Nigeria   WAT       99  Waterbodies           2
#
#                                             geometry
# 0  MULTIPOLYGON (((11.51913 6.61454, 11.51960 6.6...
# 1  POLYGON ((5.83178 13.76125, 5.78032 13.78030, ...
# 2  MULTIPOLYGON (((6.44714 4.30935, 6.44678 4.309...
# 3  MULTIPOLYGON (((13.93739 12.53061, 13.88475 12...
# 4  POLYGON ((7.17539 11.91021, 7.11702 12.00231, ...
# 5  POLYGON ((12.95992 9.43936, 12.95996 9.43937, ...
# ...

# %%
len(Nigeria_WSR)
# Out:
# 7

# %%
Nigeria_WSR.plot()
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(1, figsize=(4.5,10))
Nigeria_WSR.plot(ax=ax, column="IPCC", legend=True, legend_kwds={"loc": "center left"})
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.04,0.5))
